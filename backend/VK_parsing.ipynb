# %%
import requests
import pandas as pd

# %%
TOKEN = '3e3522f30928afa8921fd4b256d79f37e5af274ebe13b4117412f9f4caa2d2f767563c48809abf12d902e'
API_VERSION = '5.110'

# %%
#group_id = '932' # МФТИ ОФИЦ ГРУППА
#group_id = '17708' # ФРКТ
#group_id = '15787' # ФМХФ
#group_id = '17906' # ФАКИ
#group_id = '65874' # ФАЛТ
#group_id = '35717' # ФПФЭ
#group_id = '26085' # ФОПФ
#group_id = '53380416' # ФБМФ
#group_id = '1694' # ФУПМ
#group_id = '166330483' # ФПМИ

#group_id = '7984081' # ПРОФКОМ
#group_id = '73965718' # ФИЗТЕХ.СЕГОДНЯ
#group_id = '26356004' # ПОТОК

group_id_list = ['932','17708','15787','17906','65874','35717','26085','53380416','1694','166330483','7984081','73965718','26356004']

# %% [markdown]
# ### Users.search
# * did not work, error code 28

# %%
# USE THIS TO GET THE MAXIMUM SIZE IMAGE
res_users.json()['response']['items'][-1]["crop_photo"]['photo']['sizes'][-1]
# Out:
# {'height': 640,
#  'url': 'https://sun9-71.userapi.com/c846323/v846323839/1e6c8e/hHBMcwb-ghg.jpg',
#  'type': 'y',
#  'width': 640}

# %%
data2 = pd.DataFrame()
for group_id in group_id_list:
    print("group:",group_id)
    for age in range(18,25):
        res_users = requests.get('https://api.vk.com/method/users.search',
                             params={
                                 'access_token' : TOKEN,
                                 'v' : API_VERSION,
                                 'offset' : 0,
                                 'count' : 1000,
                                 'fields' : 'bdate, sex, crop_photo',
                                 'university' : 297,
                                 'age_from' : age,
                                 'age_to' : age,
                                 'has_photo' : 1,
                                 'group_id' : group_id
                             })
        pd_users = pd.DataFrame(res_users.json()['response']['items'])
        data2 = pd.concat([data2, pd_users])
        print("Data len:",len(data2))
data2.reset_index(drop=True, inplace = True)
# Out:
# group: 932
# Data len: 317
# Data len: 884
# Data len: 1466
# Data len: 2009
# Data len: 2623
# Data len: 3232
# Data len: 3907
# group: 17708
# Data len: 3963
# Data len: 4066
# Data len: 4207
# Data len: 4332
# Data len: 4459
# Data len: 4572
# Data len: 4702
# group: 15787
# Data len: 4720
# Data len: 4760
# Data len: 4811
# Data len: 4856
# Data len: 4910
# Data len: 4979
# Data len: 5082
# group: 17906
# Data len: 5126
# Data len: 5191
# Data len: 5297
# Data len: 5383
# Data len: 5510
# Data len: 5609
# Data len: 5731
# group: 65874
# Data len: 5750
# Data len: 5783
# Data len: 5823
# Data len: 5867
# Data len: 5905
# Data len: 5937
# Data len: 5980
# group: 35717
# Data len: 6003
# Data len: 6051
# Data len: 6122
# Data len: 6187
# Data len: 6255
# Data len: 6325
# Data len: 6396
# group: 26085
# Data len: 6468
# Data len: 6603
# Data len: 6727
# Data len: 6857
# Data len: 6991
# Data len: 7117
# Data len: 7240
# group: 53380416
# Data len: 7277
# Data len: 7370
# Data len: 7447
# Data len: 7526
# Data len: 7617
# Data len: 7691
# Data len: 7797
# group: 1694
# Data len: 7853
# Data len: 7966
# Data len: 8111
# Data len: 8243
# Data len: 8419
# Data len: 8591
# Data len: 8772
# group: 166330483
# Data len: 8896
# Data len: 9126
# Data len: 9365
# Data len: 9594
# Data len: 9830
# Data len: 10016
# Data len: 10145
# group: 7984081
# Data len: 10401
# Data len: 10958
# Data len: 11572
# Data len: 12146
# Data len: 12740
# Data len: 13277
# Data len: 13782
# group: 73965718
# Data len: 14118
# Data len: 14697
# Data len: 15248
# Data len: 15717
# Data len: 16205
# Data len: 16688
# Data len: 17166
# group: 26356004
# Data len: 17411
# Data len: 17903
# Data len: 18473
# Data len: 19039
# Data len: 19638
# Data len: 20212
# Data len: 20822

# %%
data2.drop_duplicates(subset ="id", inplace = True)
data2.reset_index(drop=True, inplace = True)
data2
# Out:
#              id  first_name     last_name  is_closed  can_access_closed  sex  \
# 0      17050058       Hanna        Sanoke      False               True    1
# 1     194150322     Николай      Савченко      False               True    2
# 2     281523875       Павел           Тин      False               True    2
# 3     115176673        Ваня           Сыч      False               True    2
# 4      55041195       Диана  Шаймарданова      False               True    1
# ...         ...         ...           ...        ...                ...  ...
# 4855   34670153     Николай   Кривчанский      False               True    2
# 4856  231342557      Андрей         Мухин      False               True    2
# 4857  103473706        Илья         Рябов      False               True    2
# 4858  173091965     Дмитрий   Имаметдинов      False               True    2
# 4859  107032320  Константин        Гудков      False               True    2
#
#           bdate                                         crop_photo  \
# 0           3.7  {'photo': {'album_id': -6, 'date': 1411918408,...
# 1      6.9.2001  {'photo': {'album_id': -6, 'date': 1566659567,...
# 2          30.6  {'photo': {'album_id': -6, 'date': 1581106305,...
# 3           3.7  {'photo': {'album_id': -6, 'date': 1588098951,...
# 4     3.10.2001  {'photo': {'album_id': -6, 'date': 1582982179,...
# ...         ...                                                ...
# 4855       10.8                                                NaN
# 4856  9.11.1995  {'photo': {'album_id': -6, 'date': 1553182652,...
# 4857   5.8.1995  {'photo': {'album_id': -6, 'date': 1551117496,...
# 4858        NaN                                                NaN
# 4859        3.4  {'photo': {'album_id': -6, 'date': 1395008830,...
#
#                                              track_code
# 0     80a6dc2eIdTbCcr7wTYLugPfJe0Fsv4lwj6cISwtX8NLx1...
# 1     0aff42dcBnuQuC4wiOC7CojbfLUetoEwlMC9aSdaO5bfGc...
# 2     42cba518_OuBXtGT-PRRqf6Xy6yS9y3mjZm2x--oKqx6UF...
# 3     d5abb3cdBEy2RBYCEUIJPy63wmBQ7Y7IZiSi1aA5LV4LKg...
# 4     d05e64c8MdaY6C30HzQQ4eijQTutLAu6tuab8858Lbzce2...
# ...                                                 ...
# 4855  8bc9146f6km1W8kndINb_4OksHvu0bx5d9SfjRAz2U3UIh...
# 4856  c0dc852es8wULGKPQVWEXNuvcmBx5vctBTtUVIzwuk5RQd...
# 4857  3f64eb57-Bdgj5WXlh0l8dcZ27z3sGiGiLwIqVDljZ0Uit...
# 4858  37b66268s432ND7XdOeJFVl9S-du3i9OADcUUFn6gRVMrP...
# 4859  6663f904B_Y5snEMXtges3cXhoCO0QNCY3uux0AyQpeLo5...
#
# [4860 rows x 9 columns]

# %%
data2['sex'].value_counts()
# Out:
# 2    3418
# 1    1440
# 0       2
# Name: sex, dtype: int64

# %%
data2.to_csv('vk_phystech.csv')
